# %%
from IPython.display import Image

# %% [markdown]
# # La méthode CRUD - Par terminal de commande

# %% [markdown]
# ### Pour Create/Créer une base de donnée :

# %% [markdown]
# # CREATE DATABASE nomdelabdd;

# %%
Image(filename="create.png")

# %% [markdown]
# ### Voir les bases de donnée :

# %% [markdown]
# # SHOW DATABASES;

# %%
Image(filename="show.png")

# %% [markdown]
# ### Ensuite utiliser la base de donnée pour travailler dessus :

# %% [markdown]
# # USE nomdelabdd;

# %%
Image(filename="use.png")

# %% [markdown]
# ### Pour Creat/Créer une table et ses valeurs :

# %% [markdown]
# # CREATE TABLE nomdelatable (
# # id INTEGER NOT NULL AUTO_INCREMENT PRIMARY KEY,
# # nomvaleur type(),
# # )

# %%
Image(filename="create.png")

# %% [markdown]
# ### Pour Read/Lire les tables existantes :

# %% [markdown]
# # SHOW tables;

# %% [markdown]
# ### Pour CREATE/Créer une valeur dans la table :

# %% [markdown]
# # INSERT INTO `nomdelatable` (`nomvaleur`)
# # VALUES (`Valeurinsere`);

# %%
Image(filename="insert.png")

# %% [markdown]
# ### Pour Read/Lire à l'intérieur d'une table :

# %% [markdown]
# # SHOW COLUMNS FROM nomtable;

# %%
Image(filename="show column.png")

# %% [markdown]
# ### Pour Read/Lire TOUS (*) les éléments qui VIENNENT (FROM) nomdelatable :

# %% [markdown]
# # SELECT * FROM nomdelatable;

# %%
Image(filename="select from.png")

# %% [markdown]
# ### Pour Read/Lire UNIQUEMENT les nomvaleur :

# %% [markdown]
# # SELECT valeur, prenom, email FROM nomvaleur;

# %%
Image(filename="select.png")

# %% [markdown]
# ### Pour Read / Lire des valeurs :

# %% [markdown]
# # SELECT *(all) FROM nomtable;

# %%
Image(filename="select from.png")

# %% [markdown]
# ### Pour Update / Actualisé des valeurs :

# %% [markdown]
# # UPDATE `nomdelatable` SET `nomdelavaleur` = 'nouvellevaleur' WHERE `id` = '1';

# %% [markdown]
# ### Pour Delete / Supprimé une valeur :

# %% [markdown]
# # DELETE FROM `nomdelatable` WHERE `id` = '2';

# %% [markdown]
# ### Pour Delete / Supprimé toutes les valeurs de la table

# %% [markdown]
# # DELETE FROM nomdelatable;

# %%
Image(filename="delet.png")

# %% [markdown]
# ### Pour Delete / Supprimé une table/Base de donnée :

# %% [markdown]
# # DROP TABLE/DATABASE `nomdelatable` ou `nombdd` ;

# %%
Image(filename="drop.png")

# %% [markdown]
# ### Les jointures

# %% [markdown]
# ### Pour joindre avec des valeurs correspondantes

# %% [markdown]
# # INNER JOIN

# %% [markdown]
# ### retourne toutes les lignes de la table de droite et les lignes correspondantes de la table de gauche.

# %% [markdown]
# # RIGHT JOIN

# %% [markdown]
# ### retourne toutes les lignes de la table de gauche et les lignes correspondantes de la table de droite
